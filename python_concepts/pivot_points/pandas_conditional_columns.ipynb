# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({"Col1": [10, 20, 15, 30, 45, 50, 55, 60, 65, 70],
                   "Col2": [13, 23, 18, 33, 48, 51, 54, 57, 60, 63],
                   "Col3": [17, 27, 22, 37, 52, 53, 54, 55, 56, 57]})
print(df)
# Out:
#    Col1  Col2  Col3
# 0    10    13    17
# 1    20    23    27
# 2    15    18    22
# 3    30    33    37
# 4    45    48    52
# 5    50    51    53
# 6    55    54    54
# 7    60    57    55
# 8    65    60    56
# 9    70    63    57

# %%
df["Col4"] = df["Col1"][(df["Col2"] < df["Col3"]) & (df["Col1"] > 25)]
print(df)

# Define a new "Col4" whose values are equal to "Col1" IF "[(df["Col2"] < df["Col3"]) & (df["Col1"] > 25)]" condition
# is true, otherwise it is NaN.
# Out:
#    Col1  Col2  Col3  Col4
# 0    10    13    17   NaN
# 1    20    23    27   NaN
# 2    15    18    22   NaN
# 3    30    33    37  30.0
# 4    45    48    52  45.0
# 5    50    51    53  50.0
# 6    55    54    54   NaN
# 7    60    57    55   NaN
# 8    65    60    56   NaN
# 9    70    63    57   NaN
